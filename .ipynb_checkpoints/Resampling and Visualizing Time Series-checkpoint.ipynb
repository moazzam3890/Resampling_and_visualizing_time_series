# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# <h5>Dataframes<h5>

# %%
df_bc_search = pd.read_csv('Data/Bitcoin Search Trend.csv')
df_bc_price = pd.read_csv('Data/Daily Bitcoin Price.csv')
df_tesla = pd.read_csv('Data/TESLA Search Trend vs Price.csv')
df_ue_2004_2019 = pd.read_csv('Data/UE Benefits Search vs UE Rate 2004-19.csv')
df_ue_2004_2020 = pd.read_csv('Data/UE Benefits Search vs UE Rate 2004-20.csv')

# %%
print(f'{df_tesla.head()}\n\n{df_tesla.shape}\n\n{df_tesla.tail()}')
# Out:
#         MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0  2010-06-01                3           4.766
# 1  2010-07-01                3           3.988
# 2  2010-08-01                2           3.896
# 3  2010-09-01                2           4.082
# 4  2010-10-01                2           4.368
#
# (124, 3)
#
#           MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 119  2020-05-01               16      167.000000
# 120  2020-06-01               17      215.962006
# 121  2020-07-01               24      286.152008
# 122  2020-08-01               23      498.320007
# 123  2020-09-01               31      407.339996

# %%
df_tesla.shape
# Out:
# (124, 3)

# %%
print(f'{df_ue_2004_2019.head()}\n\n{df_ue_2004_2019.shape}\n\n{df_ue_2004_2019.tail()}')
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                      34     5.7
# 1  2004-02                      33     5.6
# 2  2004-03                      25     5.8
# 3  2004-04                      29     5.6
# 4  2004-05                      23     5.6
#
# (181, 3)
#
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 176  2018-09                      14     3.7
# 177  2018-10                      15     3.8
# 178  2018-11                      16     3.7
# 179  2018-12                      17     3.9
# 180  2019-01                      21     4.0

# %%
print(f'{df_ue_2004_2020.head()}\n\n{df_ue_2004_2020.shape}\n\n{df_ue_2004_2020.tail()}')
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                       9     5.7
# 1  2004-02                       8     5.6
# 2  2004-03                       7     5.8
# 3  2004-04                       8     5.6
# 4  2004-05                       6     5.6
#
# (200, 3)
#
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 195  2020-04                     100    14.7
# 196  2020-05                      63    13.3
# 197  2020-06                      53    11.1
# 198  2020-07                      54    10.2
# 199  2020-08                      50     8.4

# %%
print(f'{df_bc_price.head()}\n\n{df_bc_price.shape}\n\n{df_bc_price.tail()}')
# Out:
#          DATE       CLOSE      VOLUME
# 0  2014-09-17  457.334015  21056800.0
# 1  2014-09-18  424.440002  34483200.0
# 2  2014-09-19  394.795990  37919700.0
# 3  2014-09-20  408.903992  36863600.0
# 4  2014-09-21  398.821014  26580100.0
#
# (2204, 3)
#
#             DATE         CLOSE        VOLUME
# 2199  2020-09-24  10745.548828  2.301754e+10
# 2200  2020-09-25  10702.290039  2.123255e+10
# 2201  2020-09-26  10754.437500  1.810501e+10
# 2202  2020-09-27  10774.426758  1.801688e+10
# 2203  2020-09-28  10912.536133  2.122653e+10

# %%
print(f'{df_bc_search.head()}\n\n{df_bc_search.shape}\n\n{df_bc_search.tail()}')
# Out:
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5
#
# (73, 2)
#
#       MONTH  BTC_NEWS_SEARCH
# 68  2020-05               22
# 69  2020-06               13
# 70  2020-07               14
# 71  2020-08               16
# 72  2020-09               13

# %%
df_tesla.TSLA_WEB_SEARCH.max()
# Out:
# 31

# %%
df_tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
print(f'Number of NaN values in Bitcoin Search DF = {df_bc_search.isna().values.sum()}')
print(f'Number of NaN values in Bitcoin Price DF = {df_bc_price.isna().values.sum()}')
print(f'Number of NaN values in Tesla DF = {df_tesla.isna().values.sum()}')
print(f'Number of NaN values in UE-2004-2019 DF = {df_ue_2004_2019.isna().values.sum()}')
print(f'Number of NaN values in UE-2004-2020 DF = {df_ue_2004_2020.isna().values.sum()}')
# Out:
# Number of NaN values in Bitcoin Search DF = 0
# Number of NaN values in Bitcoin Price DF = 2
# Number of NaN values in Tesla DF = 0
# Number of NaN values in UE-2004-2019 DF = 0
# Number of NaN values in UE-2004-2020 DF = 0

# %%
df_bc_price.CLOSE.isnull().values.any()
# Out:
# True

# %%
df_bc_price[df_bc_price.CLOSE.isna()]
# Out:
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
df_bc_price[df_bc_price['CLOSE'] == 11747.022461]
# Out:
#             DATE         CLOSE        VOLUME
# 2149  2020-08-05  11747.022461  2.441125e+10

# %%
df_bc_price['CLOSE'][2149]
# Out:
# 11747.022461

# %%
df_bc_price.dropna(inplace=True)

# %%
type(df_bc_price.DATE[1])
# Out:
# str

# %%
type(df_bc_search.MONTH[1])
# Out:
# str

# %%
type(df_tesla.MONTH[1])
# Out:
# str

# %%
type(df_ue_2004_2019.MONTH[1])
# Out:
# str

# %%
type(df_ue_2004_2020.MONTH[1])
# Out:
# str

# %%
df_bc_price['DATE'] = pd.to_datetime(df_bc_price['DATE'])

# %%
type(df_bc_price.DATE[1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_bc_search['MONTH'] = pd.to_datetime(df_bc_search['MONTH'])

# %%
df_tesla['MONTH'] = pd.to_datetime(df_tesla['MONTH'])

# %%
df_ue_2004_2019['MONTH'] = pd.to_datetime(df_ue_2004_2019['MONTH'])

# %%
df_ue_2004_2020['MONTH'] = pd.to_datetime(df_ue_2004_2020['MONTH'])

# %%
df_bc_price_monthly = df_bc_price.resample('M', on='DATE').last()

# %%
df_bc_price_monthly.tail()
# Out:
#                  DATE         CLOSE        VOLUME
# DATE
# 2020-05-31 2020-05-31   9461.058594  2.777329e+10
# 2020-06-30 2020-06-30   9137.993164  1.573580e+10
# 2020-07-31 2020-07-31  11323.466797  2.316047e+10
# 2020-08-31 2020-08-31  11680.820313  2.228593e+10
# 2020-09-30 2020-09-28  10912.536133  2.122653e+10

# %% [markdown]
# <h5>Data Visualization<h5>

# %%
plt.figure(figsize=(15,10), dpi=200)
plt.xticks(fontsize=13, rotation=45)
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color='darkgrey', linewidth=3)
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color='salmon')

ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('Stock Price', fontsize=14, color='darkgrey')
ax2.set_ylabel('Web Search', fontsize=14, color='salmon')

plt.show()

# %% [markdown]
# <h5>Locator and Date Formatter<h5>

# %%
years = mdates.YearLocator()
months = mdates.MonthLocator()
fmt = mdates.DateFormatter('%Y')

# %%
plt.figure(figsize=(15,10), dpi=120)
plt.title('Tesla Stock Price VS Web Search', fontsize=16)
plt.xticks(fontsize=13, rotation=45)
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color='darkgrey', linewidth=3)
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color='salmon')

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_minor_locator(months)
ax1.xaxis.set_major_formatter(fmt)

ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('Stock Price', fontsize=14, color='darkgrey')
ax2.set_ylabel('Web Search', fontsize=14, color='salmon')

plt.show()

# %%
plt.figure(figsize=(15,10), dpi=120)
plt.title('Bitcoin News Search VS Resampled Price', fontsize=16)
plt.xticks(fontsize=13, rotation=45)
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(df_bc_price_monthly.DATE, df_bc_price_monthly.CLOSE,linestyle='--', color='darkgrey',linewidth=3,marker='o')
ax2.plot(df_bc_search.MONTH, df_bc_search.BTC_NEWS_SEARCH, color='salmon', marker='o')

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_minor_locator(months)
ax1.xaxis.set_major_formatter(fmt)

ax1.set_xlim([df_bc_search.MONTH.min(), df_bc_search.MONTH.max()])
ax1.set_ylim(bottom = df_bc_price_monthly.CLOSE.min(), top = 15000)
# ax2.set_ylim([df_bc_search.BTC_NEWS_SEARCH.min(), df_bc_search.BTC_NEWS_SEARCH.max()])
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('BTC Price', fontsize=14, color='darkgrey')
ax2.set_ylabel('Web Search', fontsize=14, color='salmon')

plt.show()

# %%
df_bc_search.MONTH.head()
# Out:
# 0   2014-09-01
# 1   2014-10-01
# 2   2014-11-01
# 3   2014-12-01
# 4   2015-01-01
# Name: MONTH, dtype: datetime64[ns]

# %%
df_ue_2004_2019.head()
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0 2004-01-01                      34     5.7
# 1 2004-02-01                      33     5.6
# 2 2004-03-01                      25     5.8
# 3 2004-04-01                      29     5.6
# 4 2004-05-01                      23     5.6

# %%
plt.figure(figsize=(15,10), dpi=120)
plt.title('Monthly Search of "Unemployment Benefits" in the US vs the U/E Rate', fontsize=16)
# plt.grid(color='r', linestyle='--', linewidth=1)
plt.xticks(fontsize=13, rotation=45)
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.grid(color='r', linestyle='--')

ax1.plot(df_ue_2004_2019.MONTH, df_ue_2004_2019.UE_BENEFITS_WEB_SEARCH,linestyle='--', color='darkgrey',linewidth=3,marker='o')
ax2.plot(df_ue_2004_2019.MONTH, df_ue_2004_2019.UNRATE, color='salmon', marker='o')

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_minor_locator(months)
ax1.xaxis.set_major_formatter(fmt)

ax1.set_xlim([df_ue_2004_2019.MONTH.min(), df_ue_2004_2019.MONTH.max()])
# ax1.set_ylim(bottom = df_ue_2004_2020.UE_BENEFITS_WEB_SEARCH.min(), top = df_ue_2004_2020.UE_BENEFITS_WEB_SEARCH.max()+10)
# ax2.set_ylim([df_bc_search.BTC_NEWS_SEARCH.min(), df_bc_search.BTC_NEWS_SEARCH.max()])
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('U/E Benefits Web Search', fontsize=14, color='darkgrey')
ax2.set_ylabel('FRED U/E Rate', fontsize=14, color='salmon')

plt.show()

# %%
roll_df = df_ue_2004_2019[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()

# %%
roll_df.head(10)
# Out:
#    UE_BENEFITS_WEB_SEARCH    UNRATE
# 0                     NaN       NaN
# 1                     NaN       NaN
# 2                     NaN       NaN
# 3                     NaN       NaN
# 4                     NaN       NaN
# 5               28.833333  5.650000
# 6               27.500000  5.616667
# 7               26.333333  5.583333
# 8               26.000000  5.516667
# 9               25.500000  5.500000

# %%
plt.figure(figsize=(15,10), dpi=120)
plt.title('Monthly Search of "Unemployment Benefits" in the US vs the U/E Rate', fontsize=16)
# plt.grid(color='r', linestyle='--', linewidth=1)
plt.xticks(fontsize=13, rotation=45)
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.grid(color='r', linestyle='--')

ax1.plot(df_ue_2004_2019.MONTH, roll_df.UE_BENEFITS_WEB_SEARCH,linestyle='--', color='darkgrey',linewidth=3,marker='o')
ax2.plot(df_ue_2004_2019.MONTH, roll_df.UNRATE, color='salmon', marker='o')

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_minor_locator(months)
ax1.xaxis.set_major_formatter(fmt)

ax1.set_xlim([df_ue_2004_2019.MONTH.min(), df_ue_2004_2019.MONTH.max()])
# ax1.set_ylim(bottom = df_ue_2004_2020.UE_BENEFITS_WEB_SEARCH.min(), top = df_ue_2004_2020.UE_BENEFITS_WEB_SEARCH.max()+10)
# ax2.set_ylim([df_bc_search.BTC_NEWS_SEARCH.min(), df_bc_search.BTC_NEWS_SEARCH.max()])
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('U/E Benefits Web Search', fontsize=14, color='darkgrey')
ax2.set_ylabel('FRED U/E Rate', fontsize=14, color='salmon')

plt.show()

# %%
plt.figure(figsize=(15,10), dpi=120)
plt.title('Monthly Search of "Unemployment Benefits" in the US vs the U/E Rate Including 2020', fontsize=16)
# plt.grid(color='r', linestyle='--', linewidth=1)
plt.xticks(fontsize=13, rotation=45)
ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.grid(color='r', linestyle='--')

ax1.plot(df_ue_2004_2020.MONTH, df_ue_2004_2020.UE_BENEFITS_WEB_SEARCH,linestyle='--', color='darkgrey',linewidth=3,marker='o')
ax2.plot(df_ue_2004_2020.MONTH, df_ue_2004_2020.UNRATE, color='salmon', marker='o')

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_minor_locator(months)
ax1.xaxis.set_major_formatter(fmt)

ax1.set_xlim([df_ue_2004_2020.MONTH.min(), df_ue_2004_2020.MONTH.max()])
# ax1.set_ylim(bottom = df_ue_2004_2020.UE_BENEFITS_WEB_SEARCH.min(), top = df_ue_2004_2020.UE_BENEFITS_WEB_SEARCH.max()+10)
# ax2.set_ylim([df_bc_search.BTC_NEWS_SEARCH.min(), df_bc_search.BTC_NEWS_SEARCH.max()])
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('U/E Benefits Web Search', fontsize=14, color='darkgrey')
ax2.set_ylabel('FRED U/E Rate', fontsize=14, color='salmon')

plt.show()
